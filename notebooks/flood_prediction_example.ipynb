# %% [markdown]
# # Flood Prediction System - Example Usage
#
# This notebook demonstrates the basic usage of the Flood Prediction System.
#
# ## Overview
# The system generates synthetic flood data, trains multiple ML models, and provides interactive visualizations.

# %%
# Import required libraries
import sys
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Add src to path
sys.path.append(str(Path.cwd() / "src"))

# Import system components
from src.data.pipeline import FloodDataGenerator
from src.models.flood_models import FloodPredictionModels
from src.viz.visualization import FloodVisualizer

# %% [markdown]
# ## 1. Generate Synthetic Flood Data

# %%
# Initialize data generator
generator = FloodDataGenerator()

# Generate dataset
dataset = generator.generate_dataset()

print(f"Generated {len(dataset['processed_data'])} samples")
print(f"Features: {len(dataset['feature_names'])}")
print(f"Flood risk rate: {dataset['y_train'].mean():.3f}")
